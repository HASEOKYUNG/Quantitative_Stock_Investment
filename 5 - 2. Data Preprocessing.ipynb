# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import FinanceDataReader as fdr
import pandas_datareader.data as pdr
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import pywt
import talib
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# ignore warnings
import warnings ; warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
# 분석 시점은 2013년 10월부터 2023년 6월까지로 설정한다.
start, end = '2013-10-01', '2023-07-02'

# %% [markdown]
# - #### 주식 데이터
#   Microsoft, Amazon, Intel, McDonald, Apple 주식을 수집한다.

# %%
msft = fdr.DataReader('MSFT', start, end)
amzn = fdr.DataReader('AMZN', start, end)
intc = fdr.DataReader('INTC', start, end)
mcd = fdr.DataReader('MCD', start, end)    
aapl = fdr.DataReader('AAPL', start, end)
display(msft)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-10-01   33.349998   33.610001   33.299999   33.580002   28.120390
# 2013-10-02   33.360001   34.029999   33.290001   33.919998   28.405107
# 2013-10-03   33.880001   34.000000   33.419998   33.860001   28.354864
# 2013-10-04   33.689999   33.990002   33.619999   33.880001   28.371611
# 2013-10-07   33.599998   33.709999   33.200001   33.299999   27.885908
# ...                ...         ...         ...         ...         ...
# 2023-06-26  333.720001  336.109985  328.489990  328.600006  327.905762
# 2023-06-27  331.859985  336.149994  329.299988  334.570007  333.863159
# 2023-06-28  334.660004  337.980011  333.809998  335.850006  335.140442
# 2023-06-29  334.709991  336.109985  332.619995  335.049988  334.342102
# 2023-06-30  337.750000  342.730011  337.200012  340.540009  339.820526
#
#               Volume
# Date
# 2013-10-01  36718700
# 2013-10-02  46946800
# 2013-10-03  38703800
# 2013-10-04  33008100
# 2013-10-07  35069300
# ...              ...
# 2023-06-26  21520600
# 2023-06-27  24354100
# 2023-06-28  20259500
# 2023-06-29  16997000
# 2023-06-30  26823800
#
# [2454 rows x 6 columns]

# %% [markdown]
# - #### 경제지표
# GDP(국내총생산), CPI(소비자물가지수), PPI(생산자물가지수), 실업률, 3년금리, 환율,<br>
# 소매 판매 지수, 무역 수지, S&P500의 변동지수, 나스닥, 원유가격, S&P500, SOX(반도체지수)
#    - 경기선행지수는 결측치로 제외한다.

# %%
econ = ['GDP', 'CPIAUCNS', 'PPIACO', 'UNRATE', 'GS3', 'DEXUSEU', 
        'RSAFS', 'NETEXC', 'VIXCLS', 'NASDAQCOM', 'DCOILWTICO']

economics = pd.DataFrame({'DATE': pd.date_range('2013-10-01','2023-07-01')})
for code in econ:
    economics = economics.merge(pdr.DataReader(code, 'fred', start, end), on='DATE', how='left')

# %%
# S&P500, SOX(반도체지수)는 별도로 수집한다.
economics = economics.merge(pd.concat([fdr.DataReader('S&P500', start, end)['Adj Close'], 
                                       yf.download("^SOX", start, end)['Adj Close']], axis=1).reset_index(),
                            left_on='DATE', right_on='Date', how='left')
economics.set_index('DATE', inplace=True)
economics.drop(['Date'], axis=1, inplace=True)
economics.columns=['GDP','CPI','PPI','UNRATE', 'IR', 'ER', 'RS', 'TB', 'VIX', 'NASDAQ', 'OP', 'SP500', 'SOX']
economics = economics.fillna(method='backfill')
display(economics)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ha\AppData\Local\Temp\ipykernel_17872\1879210743.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   economics = economics.fillna(method='backfill')
#                   GDP      CPI      PPI  UNRATE    IR      ER        RS  \
# DATE
# 2013-10-01  17192.019  233.546  202.500     7.2  0.63  1.3534  419288.0
# 2013-10-02  17197.738  233.069  201.200     6.9  0.58  1.3592  420468.0
# 2013-10-03  17197.738  233.069  201.200     6.9  0.58  1.3642  420468.0
# 2013-10-04  17197.738  233.069  201.200     6.9  0.58  1.3582  420468.0
# 2013-10-05  17197.738  233.069  201.200     6.9  0.58  1.3569  420468.0
# ...               ...      ...      ...     ...   ...     ...       ...
# 2023-06-27  27623.543  305.691  253.889     3.5  4.47  1.0961  694415.0
# 2023-06-28  27623.543  305.691  253.889     3.5  4.47  1.0904  694415.0
# 2023-06-29  27623.543  305.691  253.889     3.5  4.47  1.0881  694415.0
# 2023-06-30  27623.543  305.691  253.889     3.5  4.47  1.0920  694415.0
# 2023-07-01  27623.543  305.691  253.889     3.5  4.47     NaN  694415.0
#
#                  TB    VIX    NASDAQ      OP        SP500          SOX
# DATE
# 2013-10-01 -275.552  15.54   3817.98  102.09  1695.000000   495.769989
# 2013-10-02 -329.736  16.60   3815.02  104.15  1693.869995   495.100006
# 2013-10-03 -329.736  17.67   3774.34  103.29  1678.660034   493.799988
# 2013-10-04 -329.736  16.74   3807.75  103.83  1690.500000   497.720001
# 2013-10-05 -329.736  19.41   3770.38  103.07  1676.119995   495.089996
# ...             ...    ...       ...     ...          ...          ...
# 2023-06-27 -937.655  13.74  13555.67   67.68  4378.410156  3642.409912
# 2023-06-28 -937.655  13.43  13591.75   69.54  4376.859863  3609.479980
# 2023-06-29 -937.655  13.54  13591.33   69.85  4396.439941  3614.179932
# 2023-06-30 -937.655  13.59  13787.92   70.66  4450.379883  3673.060059
# 2023-07-01 -937.655    NaN       NaN     NaN          NaN          NaN
#
# [3561 rows x 13 columns]

# %% [markdown]
# - #### 재무제표
#   stockanalysis 사이트를 통해 10년치 재무제표를 크롤링한다.

# %%
def FS(ticker):
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
    url = f"https://stockanalysis.com/stocks/{ticker}/financials/?p=quarterly"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    element_tables = soup.select("table[data-test='financials']")
    # 매출성장률, EPS 성장률
    df = pd.read_html(str(element_tables))[0].set_index('Quarter Ended')
    df = df.loc[['Revenue Growth (YoY)', 'EPS Growth']]

    url = f"https://stockanalysis.com/stocks/{ticker}/financials/ratios/?p=quarterly"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    element_tables = soup.select("table[class='contain']")
    df2 = pd.read_html(str(element_tables))[0].set_index('Quarter Ended')
    df2 = df2.loc[['PE Ratio', 'PB Ratio','Debt / Equity Ratio', 'Quick Ratio', 'Dividend Yield']]
    df = pd.concat([df, df2])
    return df

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
url = "https://stockanalysis.com/stocks/aapl/financials/ratios/?p=quarterly"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.select('id'='main')
# //*[@id="main"]
# Out:
#   Cell In[46], line 1
#     soup.select('id'='main')
#                 ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
amzn_fs = FS('amzn')
intc_fs = FS('intc')
mcd_fs = FS('mcd')
aapl_fs = FS('aapl')
display(msft_fs)
# Out:
# C:\Users\ha\AppData\Local\Temp\ipykernel_17872\1874832255.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(element_tables))[0]
# C:\Users\ha\AppData\Local\Temp\ipykernel_17872\1874832255.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(element_tables))[0]
# C:\Users\ha\AppData\Local\Temp\ipykernel_17872\1874832255.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(element_tables))[0]
# C:\Users\ha\AppData\Local\Temp\ipykernel_17872\1874832255.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(element_tables))[0]
# C:\Users\ha\AppData\Local\Temp\ipykernel_17872\1874832255.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_html(str(element_tables))[0]
#                    Quarter Ended 2023-09-30 2023-06-30 2023-03-31 2022-12-31  \
# 0                        Revenue      56517      56189      52857      52747
# 1           Revenue Growth (YoY)     12.76%      8.34%      7.08%      1.97%
# 2                Cost of Revenue      16302      16795      16128      17488
# 3                   Gross Profit      40215      39394      36729      35259
# 4       Selling, General & Admin       6661       8401       7393       8016
# 5         Research & Development       6659       6739       6984       6844
# 6       Other Operating Expenses          0          0          0          0
# 7             Operating Expenses      13320      15140      14377      14860
# 8               Operating Income      26895      24254      22352      20399
# 9      Interest Expense / Income        525        482        496        490
# 10        Other Expense / Income       -914       -955       -817       -430
# 11                 Pretax Income      27284      24727      22673      20339
# 12                    Income Tax       4993       4646       4374       3914
# 13                    Net Income      22291      20081      18299      16425
# 14             Net Income Growth     26.97%     19.96%      9.39%    -12.47%
# 15    Shares Outstanding (Basic)       7429       7434       7441       7451
# 16  Shares Outstanding (Diluted)       7462       7466       7464       7473
# 17                 Shares Change     -0.31%     -0.51%     -0.93%     -1.09%
# 18                   EPS (Basic)       3.00       2.70       2.46       2.20
# 19                 EPS (Diluted)       2.99       2.69       2.45       2.20
# 20                    EPS Growth     27.23%     20.09%     10.36%    -11.29%
# 21                Free Cash Flow      20666      19827      17834       4899
# 22      Free Cash Flow Per Share       2.78       2.67       2.40       0.66
# 23            Dividend Per Share      0.680      0.680      0.680      0.680
# 24               Dividend Growth      9.68%      9.68%      9.68%      9.68%
# 25                  Gross Margin     71.16%     70.11%     69.49%     66.85%
# 26              Operating Margin     47.59%     43.17%     42.29%     38.67%
# 27                 Profit Margin     39.44%     35.74%     34.62%     31.14%
# 28         Free Cash Flow Margin     36.57%     35.29%     33.74%      9.29%
# 29            Effective Tax Rate     18.30%     18.79%     19.29%     19.24%
# 30                        EBITDA      31730      29083      26718      24477
# 31                 EBITDA Margin     56.14%     51.76%     50.55%     46.40%
# 32   Depreciation & Amortization       3921       3874       3549       3648
# 33                          EBIT      27809      25209      23169      20829
# 34                   EBIT Margin     49.20%     44.86%     43.83%     39.49%
#
#    2022-09-30 2022-06-30 2022-03-31 2021-12-31 2021-09-30  ... 2015-12-31  \
# 0       50122      51865      49360      51728      45317  ...      23796
# 1      10.60%     12.38%     18.35%     20.09%     21.97%  ...    -10.10%
# 2       15452      16429      15615      16960      13646  ...       9872
# 3       34670      35436      33745      34768      31671  ...      13924
# 4        6524       8053       7075       6763       5834  ...       4998
# 5        6628       6849       6306       5758       5599  ...       2900
# 6           0          0          0          0          0  ...          0
# 7       13152      14902      13381      12521      11433  ...       7898
# 8       21518      20534      20364      22247      20238  ...       6026
# 9         500        496        503        525        539  ...        309
# 10       -554       -449       -329       -793       -825  ...       -138
# 11      21572      20487      20190      22515      20524  ...       5855
# 12       4016       3747       3462       3750         19  ...        837
# 13      17556      16740      16728      18765      20505  ...       5018
# 14    -14.38%      1.71%      8.22%     21.35%     47.59%  ...    -14.41%
# 15       7457       7472       7493       7505       7513  ...       7964
# 16       7485       7504       7534       7555       7567  ...       8051
# 17     -1.08%     -1.02%     -0.83%     -0.80%     -0.92%  ...     -2.96%
# 18       2.35       2.24       2.23       2.50       2.73  ...       0.63
# 19       2.35       2.24       2.22       2.48       2.71  ...       0.62
# 20    -13.28%      3.23%      9.36%     22.17%     48.90%  ...    -12.68%
# 21      16915      17758      20046       8615      18730  ...       3594
# 22       2.27       2.38       2.67       1.15       2.49  ...       0.45
# 23      0.620      0.620      0.620      0.620      0.560  ...      0.360
# 24     10.71%     10.71%     10.71%     10.71%      9.80%  ...     16.13%
# 25     69.17%     68.32%     68.37%     67.21%     69.89%  ...     58.51%
# 26     42.93%     39.59%     41.26%     43.01%     44.66%  ...     25.32%
# 27     35.03%     32.28%     33.89%     36.28%     45.25%  ...     21.09%
# 28     33.75%     34.24%     40.61%     16.65%     41.33%  ...     15.10%
# 29     18.62%     18.29%     17.15%     16.66%      0.09%  ...     14.30%
# 30      24862      24962      24466      26536      24275  ...       7708
# 31     49.60%     48.13%     49.57%     51.30%     53.57%  ...     32.39%
# 32       2790       3979       3773       3496       3212  ...       1544
# 33      22072      20983      20693      23040      21063  ...       6164
# 34     44.04%     40.46%     41.92%     44.54%     46.48%  ...     25.90%
#
#    2015-09-30 2015-06-30 2015-03-31 2014-12-31 2014-09-30 2014-06-30  \
# 0       20379      22180      21729      26470      23201      23382
# 1     -12.16%     -5.14%      6.50%      7.96%     25.21%     17.52%
# 2        7207       7468       7161      10136       8273       7633
# 3       13172      14712      14568      16334      14928      15749
# 4        4417       5233       4800       5412       4879       6017
# 5        2962       3094       2984       2903       3065       3123
# 6           0       8438        190        243       1140        127
# 7        7379      16765       7974       8558       9084       9267
# 8        5793      -2053       6594       7776       5844       6482
# 9         249        247        211        162        161        169
# 10         31       -544       -134       -236       -213       -264
# 11       5513      -1756       6517       7850       5896       6577
# 12        611       1439       1532       1987       1356       1965
# 13       4902      -3195       4985       5863       4540       4612
# 14      7.97%          -    -11.93%    -10.60%    -13.42%     -7.11%
# 15       7996       8063       8167       8228       8249       8245
# 16       8084       8137       8237       8297       8351       8363
# 17     -3.20%     -2.70%     -1.55%     -1.17%     -0.98%     -1.19%
# 18       0.61      -0.38       0.61       0.71       0.55       0.56
# 19       0.61      -0.38       0.61       0.71       0.54       0.55
# 20     12.96%          -    -10.29%     -8.97%    -12.90%     -6.78%
# 21       7520       5068       8210       2850       7072       8455
# 22       0.94       0.63       1.00       0.35       0.86       1.02
# 23      0.310      0.310      0.310      0.310      0.280      0.280
# 24     10.71%     10.71%     10.71%     10.71%     21.74%     21.74%
# 25     64.64%     66.33%     67.04%     61.71%     64.34%     67.36%
# 26     28.43%     -9.26%     30.35%     29.38%     25.19%     27.72%
# 27     24.05%    -14.40%     22.94%     22.15%     19.57%     19.72%
# 28     36.90%     22.85%     37.78%     10.77%     30.48%     36.16%
# 29     11.08%          -     23.51%     25.31%     23.00%     29.88%
# 30       7223        -16       8243       9533       7485       8488
# 31     35.44%     -0.07%     37.94%     36.01%     32.26%     36.30%
# 32       1461       1493       1515       1521       1428       1742
# 33       5762      -1509       6728       8012       6057       6746
# 34     28.27%     -6.80%     30.96%     30.27%     26.11%     28.85%
#
#    2014-03-31 2013-12-31 +84 Quarters
# 0       20403      24519      Upgrade
# 1      -0.42%     14.28%      Upgrade
# 2        5978       8322      Upgrade
# 3       14425      16197      Upgrade
# 4        4708       5480      Upgrade
# 5        2743       2748      Upgrade
# 6           0          0      Upgrade
# 7        7451       8228      Upgrade
# 8        6974       7969      Upgrade
# 9         175        135      Upgrade
# 10       -158        -44      Upgrade
# 11       6957       7878      Upgrade
# 12       1297       1320      Upgrade
# 13       5660       6558      Upgrade
# 14     -6.52%      2.84%      Upgrade
# 15       8284       8326      Upgrade
# 16       8367       8395      Upgrade
# 17     -0.74%     -0.58%      Upgrade
# 18       0.68       0.79      Upgrade
# 19       0.68       0.78      Upgrade
# 20     -5.56%      2.63%      Upgrade
# 21       8907       2681      Upgrade
# 22       1.07       0.32      Upgrade
# 23      0.280      0.280      Upgrade
# 24     21.74%     21.74%      Upgrade
# 25     70.70%     66.06%      Upgrade
# 26     34.18%     32.50%      Upgrade
# 27     27.74%     26.75%      Upgrade
# 28     43.66%     10.93%      Upgrade
# 29     18.64%     16.76%      Upgrade
# 30       8387       9274      Upgrade
# 31     41.11%     37.82%      Upgrade
# 32       1255       1261      Upgrade
# 33       7132       8013      Upgrade
# 34     34.96%     32.68%      Upgrade
#
# [35 rows x 42 columns]

# %% [markdown]
# ## Feature Generation

# %% [markdown]
# - #### 주가 데이터

# %%
def StockFeatures(DATA):
    DATA['next_rtn'] = DATA['Close']/DATA['Open'] - 1
    DATA['log_return'] = np.log(1+DATA['Adj Close'].pct_change())
    
    # 이동평균
    DATA['MA5'] = talib.SMA(DATA['Close'], timeperiod=5)
    DATA['RASD5'] = talib.SMA(talib.STDDEV(DATA['Close'], timeperiod=5, nbdev=1), timeperiod=5)
    
    return DATA

# %%
import numpy as np

# %%
StockFeatures(msft)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-10-01   33.349998   33.610001   33.299999   33.580002   28.120386
# 2013-10-02   33.360001   34.029999   33.290001   33.919998   28.405090
# 2013-10-03   33.880001   34.000000   33.419998   33.860001   28.354856
# 2013-10-04   33.689999   33.990002   33.619999   33.880001   28.371599
# 2013-10-07   33.599998   33.709999   33.200001   33.299999   27.885904
# ...                ...         ...         ...         ...         ...
# 2023-06-26  333.720001  336.109985  328.489990  328.600006  327.905762
# 2023-06-27  331.859985  336.149994  329.299988  334.570007  333.863159
# 2023-06-28  334.660004  337.980011  333.809998  335.850006  335.140442
# 2023-06-29  334.709991  336.109985  332.619995  335.049988  334.342102
# 2023-06-30  337.750000  342.730011  337.200012  340.540009  339.820526
#
#               Volume  next_rtn  log_return         MA5     RASD5
# Date
# 2013-10-01  36718700  0.006897         NaN         NaN       NaN
# 2013-10-02  46946800  0.016786    0.010074         NaN       NaN
# 2013-10-03  38703800 -0.000590   -0.001770         NaN       NaN
# 2013-10-04  33008100  0.005640    0.000590         NaN       NaN
# 2013-10-07  35069300 -0.008929   -0.017267   33.708000       NaN
# ...              ...       ...         ...         ...       ...
# 2023-06-26  21520600 -0.015342   -0.019349  334.987994  4.316865
# 2023-06-27  24354100  0.008166    0.018005  334.291998  4.069054
# 2023-06-28  20259500  0.003556    0.003818  334.750000  3.789904
# 2023-06-29  16997000  0.001016   -0.002385  333.817999  3.355740
# 2023-06-30  26823800  0.008261    0.016253  334.922003  3.485559
#
# [2454 rows x 10 columns]

# %% [markdown]
# - 재무지표

# %%
# 매출성장률
msft_fs.set_index('Quarter Ended', inplace=True)

# %%
msft_fs
# Out:
#                              2023-09-30 2023-06-30 2023-03-31 2022-12-31  \
# Quarter Ended
# Revenue                           56517      56189      52857      52747
# Revenue Growth (YoY)             12.76%      8.34%      7.08%      1.97%
# Cost of Revenue                   16302      16795      16128      17488
# Gross Profit                      40215      39394      36729      35259
# Selling, General & Admin           6661       8401       7393       8016
# Research & Development             6659       6739       6984       6844
# Other Operating Expenses              0          0          0          0
# Operating Expenses                13320      15140      14377      14860
# Operating Income                  26895      24254      22352      20399
# Interest Expense / Income           525        482        496        490
# Other Expense / Income             -914       -955       -817       -430
# Pretax Income                     27284      24727      22673      20339
# Income Tax                         4993       4646       4374       3914
# Net Income                        22291      20081      18299      16425
# Net Income Growth                26.97%     19.96%      9.39%    -12.47%
# Shares Outstanding (Basic)         7429       7434       7441       7451
# Shares Outstanding (Diluted)       7462       7466       7464       7473
# Shares Change                    -0.31%     -0.51%     -0.93%     -1.09%
# EPS (Basic)                        3.00       2.70       2.46       2.20
# EPS (Diluted)                      2.99       2.69       2.45       2.20
# EPS Growth                       27.23%     20.09%     10.36%    -11.29%
# Free Cash Flow                    20666      19827      17834       4899
# Free Cash Flow Per Share           2.78       2.67       2.40       0.66
# Dividend Per Share                0.680      0.680      0.680      0.680
# Dividend Growth                   9.68%      9.68%      9.68%      9.68%
# Gross Margin                     71.16%     70.11%     69.49%     66.85%
# Operating Margin                 47.59%     43.17%     42.29%     38.67%
# Profit Margin                    39.44%     35.74%     34.62%     31.14%
# Free Cash Flow Margin            36.57%     35.29%     33.74%      9.29%
# Effective Tax Rate               18.30%     18.79%     19.29%     19.24%
# EBITDA                            31730      29083      26718      24477
# EBITDA Margin                    56.14%     51.76%     50.55%     46.40%
# Depreciation & Amortization        3921       3874       3549       3648
# EBIT                              27809      25209      23169      20829
# EBIT Margin                      49.20%     44.86%     43.83%     39.49%
#
#                              2022-09-30 2022-06-30 2022-03-31 2021-12-31  \
# Quarter Ended
# Revenue                           50122      51865      49360      51728
# Revenue Growth (YoY)             10.60%     12.38%     18.35%     20.09%
# Cost of Revenue                   15452      16429      15615      16960
# Gross Profit                      34670      35436      33745      34768
# Selling, General & Admin           6524       8053       7075       6763
# Research & Development             6628       6849       6306       5758
# Other Operating Expenses              0          0          0          0
# Operating Expenses                13152      14902      13381      12521
# Operating Income                  21518      20534      20364      22247
# Interest Expense / Income           500        496        503        525
# Other Expense / Income             -554       -449       -329       -793
# Pretax Income                     21572      20487      20190      22515
# Income Tax                         4016       3747       3462       3750
# Net Income                        17556      16740      16728      18765
# Net Income Growth               -14.38%      1.71%      8.22%     21.35%
# Shares Outstanding (Basic)         7457       7472       7493       7505
# Shares Outstanding (Diluted)       7485       7504       7534       7555
# Shares Change                    -1.08%     -1.02%     -0.83%     -0.80%
# EPS (Basic)                        2.35       2.24       2.23       2.50
# EPS (Diluted)                      2.35       2.24       2.22       2.48
# EPS Growth                      -13.28%      3.23%      9.36%     22.17%
# Free Cash Flow                    16915      17758      20046       8615
# Free Cash Flow Per Share           2.27       2.38       2.67       1.15
# Dividend Per Share                0.620      0.620      0.620      0.620
# Dividend Growth                  10.71%     10.71%     10.71%     10.71%
# Gross Margin                     69.17%     68.32%     68.37%     67.21%
# Operating Margin                 42.93%     39.59%     41.26%     43.01%
# Profit Margin                    35.03%     32.28%     33.89%     36.28%
# Free Cash Flow Margin            33.75%     34.24%     40.61%     16.65%
# Effective Tax Rate               18.62%     18.29%     17.15%     16.66%
# EBITDA                            24862      24962      24466      26536
# EBITDA Margin                    49.60%     48.13%     49.57%     51.30%
# Depreciation & Amortization        2790       3979       3773       3496
# EBIT                              22072      20983      20693      23040
# EBIT Margin                      44.04%     40.46%     41.92%     44.54%
#
#                              2021-09-30 2021-06-30  ... 2015-12-31 2015-09-30  \
# Quarter Ended                                       ...
# Revenue                           45317      46152  ...      23796      20379
# Revenue Growth (YoY)             21.97%     21.35%  ...    -10.10%    -12.16%
# Cost of Revenue                   13646      13991  ...       9872       7207
# Gross Profit                      31671      32161  ...      13924      13172
# Selling, General & Admin           5834       7379  ...       4998       4417
# Research & Development             5599       5687  ...       2900       2962
# Other Operating Expenses              0          0  ...          0          0
# Operating Expenses                11433      13066  ...       7898       7379
# Operating Income                  20238      19095  ...       6026       5793
# Interest Expense / Income           539        553  ...        309        249
# Other Expense / Income             -825       -863  ...       -138         31
# Pretax Income                     20524      19405  ...       5855       5513
# Income Tax                           19       2947  ...        837        611
# Net Income                        20505      16458  ...       5018       4902
# Net Income Growth                47.59%     46.92%  ...    -14.41%      7.97%
# Shares Outstanding (Basic)         7513       7526  ...       7964       7996
# Shares Outstanding (Diluted)       7567       7581  ...       8051       8084
# Shares Change                    -0.92%     -0.94%  ...     -2.96%     -3.20%
# EPS (Basic)                        2.73       2.19  ...       0.63       0.61
# EPS (Diluted)                      2.71       2.17  ...       0.62       0.61
# EPS Growth                       48.90%     48.63%  ...    -12.68%     12.96%
# Free Cash Flow                    18730      16258  ...       3594       7520
# Free Cash Flow Per Share           2.49       2.16  ...       0.45       0.94
# Dividend Per Share                0.560      0.560  ...      0.360      0.310
# Dividend Growth                   9.80%      9.80%  ...     16.13%     10.71%
# Gross Margin                     69.89%     69.68%  ...     58.51%     64.64%
# Operating Margin                 44.66%     41.37%  ...     25.32%     28.43%
# Profit Margin                    45.25%     35.66%  ...     21.09%     24.05%
# Free Cash Flow Margin            41.33%     35.23%  ...     15.10%     36.90%
# Effective Tax Rate                0.09%     15.19%  ...     14.30%     11.08%
# EBITDA                            24275      23302  ...       7708       7223
# EBITDA Margin                    53.57%     50.49%  ...     32.39%     35.44%
# Depreciation & Amortization        3212       3344  ...       1544       1461
# EBIT                              21063      19958  ...       6164       5762
# EBIT Margin                      46.48%     43.24%  ...     25.90%     28.27%
#
#                              2015-06-30 2015-03-31 2014-12-31 2014-09-30  \
# Quarter Ended
# Revenue                           22180      21729      26470      23201
# Revenue Growth (YoY)             -5.14%      6.50%      7.96%     25.21%
# Cost of Revenue                    7468       7161      10136       8273
# Gross Profit                      14712      14568      16334      14928
# Selling, General & Admin           5233       4800       5412       4879
# Research & Development             3094       2984       2903       3065
# Other Operating Expenses           8438        190        243       1140
# Operating Expenses                16765       7974       8558       9084
# Operating Income                  -2053       6594       7776       5844
# Interest Expense / Income           247        211        162        161
# Other Expense / Income             -544       -134       -236       -213
# Pretax Income                     -1756       6517       7850       5896
# Income Tax                         1439       1532       1987       1356
# Net Income                        -3195       4985       5863       4540
# Net Income Growth                     -    -11.93%    -10.60%    -13.42%
# Shares Outstanding (Basic)         8063       8167       8228       8249
# Shares Outstanding (Diluted)       8137       8237       8297       8351
# Shares Change                    -2.70%     -1.55%     -1.17%     -0.98%
# EPS (Basic)                       -0.38       0.61       0.71       0.55
# EPS (Diluted)                     -0.38       0.61       0.71       0.54
# EPS Growth                            -    -10.29%     -8.97%    -12.90%
# Free Cash Flow                     5068       8210       2850       7072
# Free Cash Flow Per Share           0.63       1.00       0.35       0.86
# Dividend Per Share                0.310      0.310      0.310      0.280
# Dividend Growth                  10.71%     10.71%     10.71%     21.74%
# Gross Margin                     66.33%     67.04%     61.71%     64.34%
# Operating Margin                 -9.26%     30.35%     29.38%     25.19%
# Profit Margin                   -14.40%     22.94%     22.15%     19.57%
# Free Cash Flow Margin            22.85%     37.78%     10.77%     30.48%
# Effective Tax Rate                    -     23.51%     25.31%     23.00%
# EBITDA                              -16       8243       9533       7485
# EBITDA Margin                    -0.07%     37.94%     36.01%     32.26%
# Depreciation & Amortization        1493       1515       1521       1428
# EBIT                              -1509       6728       8012       6057
# EBIT Margin                      -6.80%     30.96%     30.27%     26.11%
#
#                              2014-06-30 2014-03-31 2013-12-31 +84 Quarters
# Quarter Ended
# Revenue                           23382      20403      24519      Upgrade
# Revenue Growth (YoY)             17.52%     -0.42%     14.28%      Upgrade
# Cost of Revenue                    7633       5978       8322      Upgrade
# Gross Profit                      15749      14425      16197      Upgrade
# Selling, General & Admin           6017       4708       5480      Upgrade
# Research & Development             3123       2743       2748      Upgrade
# Other Operating Expenses            127          0          0      Upgrade
# Operating Expenses                 9267       7451       8228      Upgrade
# Operating Income                   6482       6974       7969      Upgrade
# Interest Expense / Income           169        175        135      Upgrade
# Other Expense / Income             -264       -158        -44      Upgrade
# Pretax Income                      6577       6957       7878      Upgrade
# Income Tax                         1965       1297       1320      Upgrade
# Net Income                         4612       5660       6558      Upgrade
# Net Income Growth                -7.11%     -6.52%      2.84%      Upgrade
# Shares Outstanding (Basic)         8245       8284       8326      Upgrade
# Shares Outstanding (Diluted)       8363       8367       8395      Upgrade
# Shares Change                    -1.19%     -0.74%     -0.58%      Upgrade
# EPS (Basic)                        0.56       0.68       0.79      Upgrade
# EPS (Diluted)                      0.55       0.68       0.78      Upgrade
# EPS Growth                       -6.78%     -5.56%      2.63%      Upgrade
# Free Cash Flow                     8455       8907       2681      Upgrade
# Free Cash Flow Per Share           1.02       1.07       0.32      Upgrade
# Dividend Per Share                0.280      0.280      0.280      Upgrade
# Dividend Growth                  21.74%     21.74%     21.74%      Upgrade
# Gross Margin                     67.36%     70.70%     66.06%      Upgrade
# Operating Margin                 27.72%     34.18%     32.50%      Upgrade
# Profit Margin                    19.72%     27.74%     26.75%      Upgrade
# Free Cash Flow Margin            36.16%     43.66%     10.93%      Upgrade
# Effective Tax Rate               29.88%     18.64%     16.76%      Upgrade
# EBITDA                             8488       8387       9274      Upgrade
# EBITDA Margin                    36.30%     41.11%     37.82%      Upgrade
# Depreciation & Amortization        1742       1255       1261      Upgrade
# EBIT                               6746       7132       8013      Upgrade
# EBIT Margin                      28.85%     34.96%     32.68%      Upgrade
#
# [35 rows x 41 columns]

# %%
msft_fs.loc[['Revenue Growth (YoY)', 'EPS Growth'

# %%
msft_fs.index
# Out:
# Index(['Revenue', 'Revenue Growth (YoY)', 'Cost of Revenue', 'Gross Profit',
#        'Selling, General & Admin', 'Research & Development',
#        'Other Operating Expenses', 'Operating Expenses', 'Operating Income',
#        'Interest Expense / Income', 'Other Expense / Income', 'Pretax Income',
#        'Income Tax', 'Net Income', 'Net Income Growth',
#        'Shares Outstanding (Basic)', 'Shares Outstanding (Diluted)',
#        'Shares Change', 'EPS (Basic)', 'EPS (Diluted)', 'EPS Growth',
#        'Free Cash Flow', 'Free Cash Flow Per Share', 'Dividend Per Share',
#        'Dividend Growth', 'Gross Margin', 'Operating Margin', 'Profit Margin',
#        'Free Cash Flow Margin', 'Effective Tax Rate', 'EBITDA',
#        'EBITDA Margin', 'Depreciation & Amortization', 'EBIT', 'EBIT Margin'],
#       dtype='object', name='Quarter Ended')

# %% [markdown]
# ## Wavelet Transformation

# %%
cwtmatr, freqs = pywt.cwt(, np.arange(-1, 1, 0.0001), "morl")

# %% [markdown]
# ## Auto-encoder
