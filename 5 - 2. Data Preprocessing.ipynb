# %% [markdown]
# ## Import

# %%
import pandas as pd
import FinanceDataReader as fdr
import pandas_datareader.data as pdr
import yfinance as yfin
import pywt
import talib

# %% [markdown]
# ## Read Data

# %%
# 주식 데이터
msft = fdr.DataReader('MSFT', '2000-01-01', '2023-10-31')
amzn = fdr.DataReader('AMZN', '2000-01-01', '2023-10-31')
intc = fdr.DataReader('INTC', '2000-01-01', '2023-10-31')
jhj = fdr.DataReader('JHJ', '2000-01-01', '2023-10-31')
aapl = fdr.DataReader('AAPL', '2000-01-01', '2023-10-31')

# %%
# 경제지표
gpd = pdr.DataReader('GDP', 'fred', start='2000-01-01', end='2023-10-31')
cpi = pdr.DataReader('CPIAUCNS', 'fred',  start='2000-01-01', end='2023-10-31')
une = pdr.DataReader('UNRATE', 'fred', start='2000-01-01', end='2023-10-31')
ir = pdr.DataReader('GS10', 'fred', start='2000-01-01', end='2023-10-31')
lei = pdr.DataReader('USSLIND', 'fred', start='2000-01-01', end='2023-10-31')
sox = pdr.DataReader('^SOX', 'yahoo', start='2000-01-01', end='2023-10-31')
vix = pdr.DataReader('VIXCLS', 'fred', start='2000-01-01', end='2023-10-31')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 7>()
#       5 ir = pdr.DataReader('GS10', 'fred', start='2000-01-01', end='2023-10-31')
#       6 lei = pdr.DataReader('USSLIND', 'fred', start='2000-01-01', end='2023-10-31')
# ----> 7 sox = pdr.DataReader('^SOX', 'yahoo', start='2000-01-01', end='2023-10-31')
#       8 vix = pdr.DataReader('VIXCLS', 'fred', start='2000-01-01', end='2023-10-31')
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas_datareader\data.py:370, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
# ...

# %% [markdown]
# ## Wavelet Transformation

# %%
cwtmatr, freqs = pywt.cwt(, np.arange(-1, 1, 0.0001), "morl")

# %% [markdown]
# ## Auto-encoder
